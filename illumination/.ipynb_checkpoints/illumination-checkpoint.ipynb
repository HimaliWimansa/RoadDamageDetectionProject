# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

input_folder = "frames"
enhanced_folder = "histogram_equalized_frames"

os.makedirs(enhanced_folder, exist_ok=True)

def contrast_stretch(image):
    min_val = np.min(image)
    max_val = np.max(image)

    if max_val - min_val == 0:
        return image.copy()

    stretched = (image.astype(np.float32) - min_val) * (255.0 / (max_val - min_val))
    return stretched.astype(np.uint8)

def calculate_entropy(image):
    hist = cv2.calcHist([image],[0],None,[256],[0,256])
    hist = hist / hist.sum()
    hist = hist.flatten()
    hist = hist[hist > 0]
    entropy = -np.sum(hist * np.log2(hist))
    return entropy

results = []

frame_files = sorted(os.listdir(input_folder))

display_count = 0
max_display = 5

for file in frame_files:

    if file.lower().endswith((".jpg", ".png", ".jpeg")):

        path = os.path.join(input_folder, file)
        img = cv2.imread(path, 0)

        if img is None:
            continue

        stretched = contrast_stretch(img)

        hist_eq = cv2.equalizeHist(stretched)

        cv2.imwrite(os.path.join(enhanced_folder, file), hist_eq)

        std_before = np.std(img)
        std_after = np.std(hist_eq)

        entropy_before = calculate_entropy(img)
        entropy_after = calculate_entropy(hist_eq)

        results.append([
            file,
            std_before,
            std_after,
            entropy_before,
            entropy_after
        ])

        if display_count < max_display:

            plt.figure(figsize=(10,4))

            plt.subplot(1,3,1)
            plt.imshow(img, cmap="gray")
            plt.title("Original")
            plt.axis("off")

            plt.subplot(1,3,2)
            plt.imshow(stretched, cmap="gray")
            plt.title("Contrast Stretched")
            plt.axis("off")

            plt.subplot(1,3,3)
            plt.imshow(hist_eq, cmap="gray")
            plt.title("Histogram Equalized")
            plt.axis("off")

            plt.suptitle(file)
            plt.show()
            plt.close()

            plt.figure(figsize=(6,4))

            hist_orig = cv2.calcHist([img],[0],None,[256],[0,256])
            hist_enhanced = cv2.calcHist([hist_eq],[0],None,[256],[0,256])

            plt.plot(hist_orig, label="Original")
            plt.plot(hist_enhanced, label="Enhanced")
            plt.title("Histogram Comparison")
            plt.legend()
            plt.show()
            plt.close()

            display_count += 1

print("\nIllumination Enhancement Completed.")

df = pd.DataFrame(
    results,
    columns=[
        "Frame",
        "Contrast Before (Std Dev)",
        "Contrast After (Std Dev)",
        "Entropy Before",
        "Entropy After"
    ]
)

print("\n ENHANCEMENT EVALUATION ")
print(df)

if not df.empty:
    avg_std_before = df["Contrast Before (Std Dev)"].mean()
    avg_std_after = df["Contrast After (Std Dev)"].mean()

    avg_entropy_before = df["Entropy Before"].mean()
    avg_entropy_after = df["Entropy After"].mean()

    print("\nAverage Contrast Before :", round(avg_std_before, 2))
    print("Average Contrast After  :", round(avg_std_after, 2))
    print("Average Contrast Gain   :", round(avg_std_after - avg_std_before, 2))

    print("\nAverage Entropy Before  :", round(avg_entropy_before, 2))
    print("Average Entropy After   :", round(avg_entropy_after, 2))
    print("Average Entropy Gain    :", round(avg_entropy_after - avg_entropy_before, 2))

    if avg_std_after > avg_std_before:
        print("\nInterpretation: Contrast improved according to standard deviation.")
    else:
        print("\nInterpretation: No significant contrast improvement detected.")

    if avg_entropy_after > avg_entropy_before:
        print("Interpretation: Information content increased after enhancement.")
# Out:
# Illumination Enhancement Completed.
#
#  ENHANCEMENT EVALUATION
#                                 Frame  Contrast Before (Std Dev)  \
# 0       AlligatorCracking_frame_0.jpg                  36.269324
# 1      AlligatorCracking_frame_20.jpg                  29.673844
# 2      AlligatorCracking_frame_35.jpg                  28.744779
# 3       AlligatorCracking_frame_4.jpg                  31.869362
# 4      AlligatorCracking_frame_51.jpg                  32.111230
# 5       AlligatorCracking_frame_9.jpg                  30.814222
# 6          EdgeCracking3_frame_72.jpg                  24.160179
# 7         EdgeCracking4_frame_123.jpg                  29.069805
# 8         EdgeCracking4_frame_129.jpg                  29.768169
# 9         EdgeCracking4_frame_130.jpg                  29.317244
# 10        EdgeCracking4_frame_133.jpg                  30.621638
# 11        EdgeCracking4_frame_144.jpg                  24.366259
# 12        EdgeCracking4_frame_154.jpg                  17.187518
# 13        EdgeCracking9_frame_185.jpg                  17.692339
# 14        EdgeCracking9_frame_202.jpg                  20.648950
# 15        EdgeCracking9_frame_206.jpg                  19.388725
# 16        EdgeCracking9_frame_217.jpg                  21.012886
# 17        RoadPotholes2_frame_522.jpg                  30.549918
# 18        RoadPotholes3_frame_575.jpg                  46.620305
# 19        RoadPotholes3_frame_578.jpg                  45.420583
# 20        RoadPotholes3_frame_585.jpg                  38.754915
# 21         RoadPotholes_frame_478.jpg                  32.133481
# 22         RoadPotholes_frame_479.jpg                  32.649694
# 23         RoadPotholes_frame_491.jpg                  38.513442
# 24         RoadPotholes_frame_494.jpg                  36.705867
# 25         RoadPotholes_frame_500.jpg                  34.521002
# 26  pedestrianCrossing2_frame_330.jpg                  47.601341
# 27  pedestrianCrossing2_frame_352.jpg                  44.967589
# 28  pedestrianCrossing2_frame_366.jpg                  35.646003
# 29  pedestrianCrossing2_frame_367.jpg                  31.443992
# 30   pedestrianCrossing_frame_234.jpg                  46.240910
# 31   pedestrianCrossing_frame_241.jpg                  45.671387
# 32   pedestrianCrossing_frame_246.jpg                  39.795983
#
#     Contrast After (Std Dev)  Entropy Before  Entropy After
# 0                  73.516233        7.209457       7.079047
# 1                  73.649946        6.924819       6.806917
# 2                  73.547703        6.868957       6.752831
# 3                  73.564813        7.027626       6.908139
# 4                  73.578048        7.027921       6.910365
# 5                  73.578142        6.976987       6.854585
# 6                  73.708252        6.618084       6.466607
# 7                  73.350087        6.766053       6.663555
# 8                  73.463168        6.866534       6.738520
# 9                  73.422299        6.843411       6.712290
# 10                 73.520642        6.922451       6.781512
# 11                 73.471141        6.607117       6.442533
# 12                 73.390225        6.057669       5.928224
# 13                 73.683129        6.182838       6.089323
# 14                 73.579181        6.400244       6.314219
# 15                 73.223271        6.244829       6.158083
# 16                 73.191246        6.343977       6.270744
# 17                 73.620424        6.954305       6.792785
# 18                 73.737646        7.512235       7.354926
# 19                 73.776804        7.441341       7.290206
# 20                 73.786266        7.218729       7.049945
# 21                 73.804838        6.930775       6.779809
# 22                 73.826820        6.944799       6.780386
# 23                 73.682205        7.201890       7.077268
# 24                 73.785959        7.139222       7.002465
# 25                 73.656648        7.116376       6.982498
# 26                 72.800328        6.698986       6.516111
# 27                 72.736626        6.688808       6.543062
# 28                 72.657027        6.698693       6.556378
# 29                 72.575200        6.554374       6.396426
# 30                 73.419854        7.286727       7.201689
# 31                 73.360932        7.134383       7.052158
# 32                 73.090500        6.910405       6.742437
#
# Average Contrast Before : 32.73
# Average Contrast After  : 73.45
# Average Contrast Gain   : 40.72
#
# Average Entropy Before  : 6.86
# Average Entropy After   : 6.73
# Average Entropy Gain    : -0.13
#
# Interpretation: Contrast improved according to standard deviation.
